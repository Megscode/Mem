# %%
import pandas as pd
import numpy as np
data = pd.read_csv('2020.csv')
training_data = pd.read_csv('2019.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,4))
sns.catplot(x="Ladder score", y="Social support", data=data, ax=axs[0])
sns.swarmplot(x="Ladder score", y="Generosity", data=data, ax=axs[1])
sns.catplot(x="Score", y="Social support", data=training_data, ax=axs[2])
sns.swarmplot(x="Score", y="Generosity", data=training_data, ax=axs[3])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-416c76411acc> in <module>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X_train = sc.fit_transform(x_train)
#       4 X_test = sc.transform(x_test)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# ...

# %%
x_train, x_test, y_train, y_test = data[['Freedom to make life choices','Generosity','Social support', 'Healthy life expectancy']]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-20-416c76411acc> in <module>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X_train = sc.fit_transform(x_train)
#       4 X_test = sc.transform(x_test)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# ...

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-27-9beff314af3f> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-25-95bb34163eeb> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model.fit(x_train, y_train)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     188         self : object
#     189         """
# --> 190         X, y = check_X_y(X, y)
#     191         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     192                                  sample_weight=sample_weight)
#
# /Users/student/miniconda2/envs/myenv/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...
